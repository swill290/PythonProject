# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="380" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
# ----> 3 get_ipython().system('pip install seaborn')
#
# File /lib/python3.12/site-packages/IPython/core/interactiveshell.py:2653, in InteractiveShell.system_piped(self, cmd)
#    2648     raise OSError("Background processes not supported.")
#    2650 # we explicitly do NOT return the subprocess status code, because
#    2651 # a non-None value would trigger :func:`sys.displayhook` calls.
#    2652 # Instead, we store the exit_code in user_ns.
# -> 2653 self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#
# File /lib/python3.12/site-packages/IPython/utils/_process_emscripten.py:11, in system(cmd)
#      10 def system(cmd):
# ---> 11     raise OSError("Not available")
#
# OSError: Not available

# %% [markdown]
# Load the dataset into a dataframe.

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# %% [markdown]
# To obtain the dataset, utilize the download() function as defined above:

# %%
await download(file_path, "m2_survey_data.csv")
file_name="m2_survey_data.csv"

# %% [markdown]
# Utilize the Pandas method read_csv() to load the data into a dataframe.

# %%
df = pd.read_csv("m2_survey_data.csv")

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface.While working on the downloaded version of this notebook on their local machines(Jupyter Anaconda), the learners can simply **skip the steps above,** and simply use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /lib/python312.zip/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File /lib/python312.zip/http/client.py:1327, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1326 """Send a complete request to the server."""
# -> 1327 self._send_request(method, url, body, headers, encode_chunked)
#
# File /lib/python312.zip/http/client.py:1373, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1372     body = _encode(body, 'body')
# -> 1373 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
import matplotlib.pyplot as plt
import numpy as np

# Drop missing values in ConvertedComp to avoid errors
converted_comp = df['ConvertedComp'].dropna()

# Plot histogram with density curve
plt.hist(converted_comp, bins=30, density=True, alpha=0.5, color='blue')

# Overlay a normal distribution curve
mean = converted_comp.mean()
std_dev = converted_comp.std()
x = np.linspace(converted_comp.min(), converted_comp.max(), 100)
plt.plot(x, (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2), color='red')

plt.xlabel('Converted Compensation')
plt.ylabel('Density')
plt.title('Distribution of Converted Compensation')
plt.show()

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here

# Drop missing values in ConvertedComp to avoid errors
converted_comp = df['ConvertedComp'].dropna()

# Plot the histogram
plt.hist(converted_comp, bins=30, color='skyblue', edgecolor='black', alpha=0.7)

# Set labels and title
plt.xlabel('Converted Compensation')
plt.ylabel('Frequency')
plt.title('Histogram of Converted Compensation')

# Show the plot
plt.show()

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
# Calculate the median of the 'ConvertedComp' column, excluding any missing values
median_converted_comp = df['ConvertedComp'].median()

print("The median of the 'ConvertedComp' column is:", median_converted_comp)
# Out:
# The median of the 'ConvertedComp' column is: 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
man_count = df[df['Gender'] == 'Man'].shape[0]
print("Number of responders identifying as only a Man:", man_count)
# Out:
# Number of responders identifying as only a Man: 10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
woman_median_converted_comp = df[df['Gender'] == 'Woman']['ConvertedComp'].median()
print("Median ConvertedComp for responders identifying as only a Woman:", woman_median_converted_comp)
# Out:
# Median ConvertedComp for responders identifying as only a Woman: 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
age_summary = df['Age'].describe(percentiles=[0.25, 0.5, 0.75])
print("Five-number summary for Age:\n", age_summary)
# Out:
# Five-number summary for Age:
#  count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
import matplotlib.pyplot as plt

plt.hist(df['Age'].dropna(), bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
plt.boxplot(df['ConvertedComp'].dropna())
plt.title('Box plot for ConvertedComp')
plt.ylabel('Converted Compensation')
plt.show()

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
Q1 = df['ConvertedComp'].quantile(0.25)
Q3 = df['ConvertedComp'].quantile(0.75)
IQR = Q3 - Q1
print("Inter Quartile Range for ConvertedComp:", IQR)
# Out:
# Inter Quartile Range for ConvertedComp: 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: -82830.0
# Upper Bound: 209698.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
outliers = df[(df['ConvertedComp'] < lower_bound) | (df['ConvertedComp'] > upper_bound)]
print("Number of outliers in ConvertedComp:", outliers.shape[0])
# Out:
# Number of outliers in ConvertedComp: 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
df_no_outliers = df[(df['ConvertedComp'] >= lower_bound) & (df['ConvertedComp'] <= upper_bound)]

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
# Select only numeric columns
numeric_columns = df.select_dtypes(include=['number'])

# Calculate the correlation of Age with other numerical columns
correlation_with_age = numeric_columns.corr()['Age'].drop('Age')  # Exclude self-correlation

# Print the correlation
print("Correlation of Age with other numerical columns:\n", correlation_with_age)
# Out:
# Correlation of Age with other numerical columns:
#  Respondent       0.004041
# CompTotal        0.006970
# ConvertedComp    0.105386
# WorkWeekHrs      0.036518
# CodeRevHrs      -0.020469
# Name: Age, dtype: float64

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>
